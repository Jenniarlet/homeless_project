# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

#import missingno
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df_0 = pd.read_csv('/Users/jenniferparedes/Desktop/Ds4A/Homelessness Project Data/final_pit_hic_merged - final_pit_hic_merged.csv')
print(df_0.info())
df_0.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5431 entries, 0 to 5430
# Columns: 111 entries, Year to Sheltered Total Homeless Individuals - Multiple Races
# dtypes: float64(103), int64(7), object(1)
# memory usage: 4.6+ MB
# None
#    Year CoC Number  Overall Homeless  Overall Homeless - Under 18  \
# 0  2020     AK-500              1058                        150.0
# 1  2020     AK-501               891                        176.0
# 2  2020     AL-500               848                         92.0
# 3  2020     AL-501               631                        107.0
# 4  2020     AL-502               215                         61.0
#
#    Overall Homeless - Age 18 to 24  Overall Homeless - Over 24  \
# 0                            129.0                       779.0
# 1                             68.0                       647.0
# 2                             54.0                       702.0
# 3                             24.0                       500.0
# ...

# %%
list(df_0.columns)
# Out:
# ['Year',
#  'CoC Number',
#  'Overall Homeless',
#  'Overall Homeless - Under 18',
#  'Overall Homeless - Age 18 to 24',
#  'Overall Homeless - Over 24',
#  'Overall Homeless - Female',
#  'Overall Homeless - Male',
#  'Overall Homeless - Transgender',
#  'Overall Homeless - Gender Non-Conforming',
#  'Overall Homeless - Non-Hispanic/Non-Latino',
#  'Overall Homeless - Hispanic/Latino',
#  'Overall Homeless - White',
#  'Overall Homeless - Black or African American',
#  'Overall Homeless - Asian',
#  'Overall Homeless - American Indian or Alaska Native',
#  'Overall Homeless - Native Hawaiian or Other Pacific Islander',
#  'Overall Homeless - Multiple Races',
#  'Unsheltered Homeless',
#  'Unsheltered Homeless - Under 18',
#  'Unsheltered Homeless - Age 18 to 24',
#  'Unsheltered Homeless - Over 24',
#  'Unsheltered Homeless - Female',
#  'Unsheltered Homeless - Male',
#  'Unsheltered Homeless - Transgender',
#  'Unsheltered Homeless - Gender Non-Conforming',
# ...

# %%
# Make new df with columns of interest
df = df_0[['Year',
 'CoC Number',
 'Overall Homeless',
 'Unsheltered Homeless',
 'Overall Homeless Veterans',
 'Sheltered Total Homeless',
 'Overall Homeless - Under 18',
 'Overall Homeless - Age 18 to 24',
 'Overall Homeless - Over 24',
 'Overall Homeless - Female',
 'Overall Homeless - Male',
 'Overall Homeless - Transgender',
 'Overall Homeless - Gender Non-Conforming',
 'Overall Homeless - Non-Hispanic/Non-Latino',
 'Overall Homeless - Hispanic/Latino',
 'Overall Homeless - White',
 'Overall Homeless - Black or African American',
 'Overall Homeless - Asian',
 'Overall Homeless - American Indian or Alaska Native',
 'Overall Homeless - Native Hawaiian or Other Pacific Islander',
 'Overall Homeless - Multiple Races']]
df.head()
# Out:
#    Year CoC Number  Overall Homeless  Unsheltered Homeless  \
# 0  2020     AK-500              1058                    55
# 1  2020     AK-501               891                   169
# 2  2020     AL-500               848                   247
# 3  2020     AL-501               631                   364
# 4  2020     AL-502               215                    41
#
#    Overall Homeless Veterans  Sheltered Total Homeless  \
# 0                       42.0                      1003
# 1                       52.0                       722
# 2                      120.0                       601
# 3                       66.0                       267
# 4                       13.0                       174
#
#    Overall Homeless - Under 18  Overall Homeless - Age 18 to 24  \
# 0                        150.0                            129.0
# 1                        176.0                             68.0
# 2                         92.0                             54.0
# ...

# %% [markdown]
# **EDA **
# 1. What dates is our data from?
# 2. Separate COC number & create new state columns
# 3.
# 3. Identify Overall columns of interest & put into a new df
#     - year
#     - state
#     - coc #
#     - 'Unsheltered Homeless'
#     -'Sheltered Total Homeless',
#     - Overall homeless
# 'Overall Homeless - Under 18',
#  'Overall Homeless - Age 18 to 24',
#  'Overall Homeless - Over 24',
#  'Overall Homeless - Female',
#  'Overall Homeless - Male',
#  'Overall Homeless - Transgender',
#  'Overall Homeless - Gender Non-Conforming',
#  'Overall Homeless - Non-Hispanic/Non-Latino',
#  'Overall Homeless - Hispanic/Latino',
#  'Overall Homeless - White',
#  'Overall Homeless - Black or African American',
#  'Overall Homeless - Asian',
#  'Overall Homeless - American Indian or Alaska Native',
#  'Overall Homeless - Native Hawaiian or Other Pacific Islander',
#  'Overall Homeless - Multiple Races'

# %%
# Separate state only from 'CoC Number' & place into a new columns using str.split

df[['State', 'CoC Code']]= df['CoC Number'].str.split('-', expand=True)
df.head()
# Out:
#    Year CoC Number  Overall Homeless  Unsheltered Homeless  \
# 0  2020     AK-500              1058                    55
# 1  2020     AK-501               891                   169
# 2  2020     AL-500               848                   247
# 3  2020     AL-501               631                   364
# 4  2020     AL-502               215                    41
#
#    Overall Homeless Veterans  Sheltered Total Homeless  \
# 0                       42.0                      1003
# 1                       52.0                       722
# 2                      120.0                       601
# 3                       66.0                       267
# 4                       13.0                       174
#
#    Overall Homeless - Under 18  Overall Homeless - Age 18 to 24  \
# 0                        150.0                            129.0
# 1                        176.0                             68.0
# 2                         92.0                             54.0
# ...

# %%
list(df.columns)
# Out:
# ['Year',
#  'CoC Number',
#  'Overall Homeless',
#  'Unsheltered Homeless',
#  'Overall Homeless Veterans',
#  'Sheltered Total Homeless',
#  'Overall Homeless - Under 18',
#  'Overall Homeless - Age 18 to 24',
#  'Overall Homeless - Over 24',
#  'Overall Homeless - Female',
#  'Overall Homeless - Male',
#  'Overall Homeless - Transgender',
#  'Overall Homeless - Gender Non-Conforming',
#  'Overall Homeless - Non-Hispanic/Non-Latino',
#  'Overall Homeless - Hispanic/Latino',
#  'Overall Homeless - White',
#  'Overall Homeless - Black or African American',
#  'Overall Homeless - Asian',
#  'Overall Homeless - American Indian or Alaska Native',
#  'Overall Homeless - Native Hawaiian or Other Pacific Islander',
#  'Overall Homeless - Multiple Races',
#  'State',
#  'CoC Code']

# %%
#print(type(df.State))

#1 Group overall homeless by state
h_states = df.groupby(['Year','State'])['Overall Homeless']
h_states

#df.groupby('State').unique()
 #2 make a line plot using seaborn

# %%
h_states = df.groupby(['Year','State', 'Sheltered Total Homeless', 'Unsheltered Homeless'])['Overall Homeless'].sum()
state_df = h_states.reset_index()
state_df

#note rename ''Sheltered Total Homeless' to 'Sheltered Homeless for consistency
# Out:
#       Year State  Sheltered Total Homeless  Unsheltered Homeless  \
# 0     2007    AK                       545                   123
# 1     2007    AK                       842                   132
# 2     2007    AL                       104                    15
# 3     2007    AL                       131                   134
# 4     2007    AL                       331                   125
# ...    ...   ...                       ...                   ...
# 5426  2020    WV                       114                    15
# 5427  2020    WV                       148                    46
# 5428  2020    WV                       281                    13
# 5429  2020    WV                       521                   203
# 5430  2020    WY                       489                   123
#
#       Overall Homeless
# 0                  668
# 1                  974
# 2                  119
# 3                  265
# 4                  456
# ...                ...
# ...

# %%
Us = [ 'Year', 'Overall Homeless']

overall_yr = df[Us]

h_by_yr = overall_yr.groupby('Year').sum()
h_by_yr

sns.lineplot(data=h_by_yr, x="Year", y="Overall Homeless").set(title= 'Overall Homeless Population 2007-2020')
# Out:
# [Text(0.5, 1.0, 'Overall Homeless Population 2007-2020')]

# %%
# x - year, y-  count - overall , values - sum , line plot 
#tittle: Overall Homeless over time
#add up all homeless ness for year 

#sum of overall per year 
#sns.linplot

##sns.lineplot(data=may_flights, x="year", y="passengers")

usa_df = create empty data frame with two columns year and total homelessness
for year in df
    sum = 'Overall Homeless' for the year we are currently looking at 
    add row in usa_df year = year and total homelessness = sum

# %% [markdown]
# Other things I want to graph
#
# Who are these people?
# - Bar/line chart from 2016- 2020 of sheltered vs unsheltered population
# - breakdwon of overall homeless by ethnicity & race
# - breakdown of overall homeless by age category
#
# Is it getting better or worse & for who?
# - table showing % changes in overall homeless year to year from last 3 years
# - table showing changes in age groups & ethinicty by all homeless, sheltered, non sheltered
# - which states are expiriencing more homeless ?
#
#
# Demographic Characteristics of People Experiencing Homelessness
# - by sheltered vs non
# -age & gender

# %% [markdown]
# HELPFUL CODE
# 1. pit = pit.rename(columns={'year': 'Year'}) #remaming a clumn

# %%
#TABLE overall homeless by gender

by_gender = ['CoC Number', 'Year', 'Overall Homeless',
 'Overall Homeless - Female',
 'Overall Homeless - Male',
 'Overall Homeless - Transgender',
 'Overall Homeless - Gender Non-Conforming']

overall_gender = df[by_gender]

gender_annual = overall_gender.groupby('Year').sum()
gender_annual
# Out:
#       Overall Homeless  Overall Homeless - Female  Overall Homeless - Male  \
# Year
# 2007            644020                        0.0                      0.0
# 2008            636261                        0.0                      0.0
# 2009            625688                        0.0                      0.0
# 2010            633464                        0.0                      0.0
# 2011            620218                        0.0                      0.0
# 2012            618022                        0.0                      0.0
# 2013            586612                        0.0                      0.0
# 2014            573381                        0.0                      0.0
# 2015            562969                   223627.0                 338053.0
# 2016            549798                   217228.0                 330800.0
# 2017            549325                   214295.0                 332068.0
# ...

# %%
#overall by age
by_age = ['CoC Number', 'Year', 'Overall Homeless',
 'Overall Homeless - Under 18',
 'Overall Homeless - Age 18 to 24',
 'Overall Homeless - Over 24']

overall_age = df[by_age]

age_annual = overall_age.groupby('Year').sum()
age_annual
# Out:
#       Overall Homeless  Overall Homeless - Under 18  \
# Year
# 2007            644020                          0.0
# 2008            636261                          0.0
# 2009            625688                          0.0
# 2010            633464                          0.0
# 2011            620218                          0.0
# 2012            618022                          0.0
# 2013            586612                     137355.0
# 2014            573381                     135218.0
# 2015            562969                     127370.0
# 2016            549798                     120807.0
# 2017            549325                     114158.0
# 2018            551032                     111198.0
# 2019            565736                     106621.0
# 2020            578438                     105942.0
#
#       Overall Homeless - Age 18 to 24  Overall Homeless - Over 24
# Year
# 2007                              0.0                         0.0
# ...

# %%
#overall by race
by_race = ['CoC Number', 'Year', 'Overall Homeless',
 'Overall Homeless - White',
 'Overall Homeless - Black or African American',
 'Overall Homeless - Asian',
 'Overall Homeless - American Indian or Alaska Native',
 'Overall Homeless - Native Hawaiian or Other Pacific Islander',
 'Overall Homeless - Multiple Races']

overall_race = df[by_race]

race_annual = overall_race.groupby('Year').sum()
race_annual
# Out:
#       Overall Homeless  Overall Homeless - White  \
# Year
# 2007            644020                       0.0
# 2008            636261                       0.0
# 2009            625688                       0.0
# 2010            633464                       0.0
# 2011            620218                       0.0
# 2012            618022                       0.0
# 2013            586612                       0.0
# 2014            573381                       0.0
# 2015            562969                  272841.0
# 2016            549798                  265544.0
# 2017            549325                  258922.0
# 2018            551032                  269720.0
# 2019            565736                  269758.0
# 2020            578438                  279609.0
#
#       Overall Homeless - Black or African American  Overall Homeless - Asian  \
# Year
# 2007                                           0.0                       0.0
# ...

# %%
# Create a cholorpeth map to show total homeless by state

import plotly.express as px


df_map = px.df()
geojson = px.data.election_geojson()

fig = px.choropleth(df, geojson=geojson, color="winner",
                    locations="district", featureidkey="properties.district",
                    projection="mercator", hover_data=["Bergeron", "Coderre", "Joly"]
                   )
fig.update_geos(fitbounds="locations", visible=False)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2ac7a5ee318e> in <module>
#       4
#       5
# ----> 6 df = px.data.election()
#       7 geojson = px.data.election_geojson()
#       8
#
# NameError: name 'px' is not defined

# %%
# compare % of homeless by
# 
# group by state & sum of homeless = total homeless by state 
# 2020  - filter by year
# , group by state + sum 
# value

# %%
# % change in homeless population 2016-2020

#make new df with columnsof interest 
df_c = ['Year',
'Overall Homeless',
'Unsheltered Homeless',
'Sheltered Total Homeless',]

# add calculation columns rate of change here [( old - new/old) * 100 ] for all 3 columsn  
df_change = df[df_c]

per_change =  df_change.groupby('Year', ).sum()
per_change[['Perc change Homeless', 'Perc Change Unsheltered', 'Perc Change Sheltered']]= per_change.pct_change()*100
per_change
# Out:
#       Overall Homeless  Unsheltered Homeless  Sheltered Total Homeless  \
# Year
# 2007            644020                255336                    388684
# 2008            636261                252420                    383841
# 2009            625688                226046                    399642
# 2010            633464                232860                    400604
# 2011            620218                230341                    389877
# 2012            618022                230413                    387609
# 2013            586612                194587                    392025
# 2014            573381                175089                    398292
# 2015            562969                173067                    389902
# 2016            549798                176238                    373560
# 2017            549325                189900                    359425
# 2018            551032                194143                    356889
# ...
