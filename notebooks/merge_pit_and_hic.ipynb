# %%
hic_path = '/content/drive/MyDrive/DS4_project data/Final Data sets /hic_by_coc.csv'
pit_path = '/content/drive/MyDrive/DS4_project data/Final Data sets /pit_by_coc.csv'

# %%
import pandas as pd

# %%
hic = pd.read_csv(hic_path, low_memory=False)
pit = pd.read_csv(pit_path, low_memory=False)

# %%
hic.fillna("",inplace=True)

# %%
hic
# Out:
#       Year  ... Total Beds for Households without Children (ES,TH)
# 0     2020  ...
# 1     2020  ...
# 2     2020  ...
# 3     2020  ...
# 4     2020  ...
# ...    ...  ...                                                ...
# 5898  2007  ...                                                210
# 5899  2007  ...                                                271
# 5900  2007  ...                                                717
# 5901  2007  ...                                                414
# 5902  2007  ...                                             213001
#
# [5903 rows x 167 columns]

# %%
hic['CoC Number'] = hic['CoC'] + hic['CoC Number']

# %%
hic['CoC Number']
# Out:
# 0       AK-500
# 1       AK-501
# 2       AL-500
# 3       AL-501
# 4       AL-502
#          ...
# 5898    WV-501
# 5899    WV-503
# 5900    WV-508
# 5901    WY-500
# 5902     Total
# Name: CoC Number, Length: 5903, dtype: object

# %%
# hic[hic['Year'] == 2007]
# Out:
#       Year  ... Total Beds for Households without Children (ES,TH)
# 5441  2007  ...                                              629.0
# 5442  2007  ...                                              457.0
# 5443  2007  ...                                              792.0
# 5444  2007  ...                                              270.0
# 5445  2007  ...                                               99.0
# ...    ...  ...                                                ...
# 5898  2007  ...                                              210.0
# 5899  2007  ...                                              271.0
# 5900  2007  ...                                              717.0
# 5901  2007  ...                                              414.0
# 5902  2007  ...                                           213001.0
#
# [462 rows x 167 columns]

# %%
# hic = hic.loc[:, ~hic.columns.str.contains('^Unnamed')]
# hic.to_csv('/content/drive/MyDrive/DS4_project data/Final Data sets /hic_by_coc.csv', index=False)

# %%
hic.dtypes
# Out:
# Year                                                    int64
# CoC Number                                             object
# Total Year-Round Beds (ES, TH, SH)                    float64
# Total Non-DV Year-Round Beds (ES, TH, SH)             float64
# Total HMIS Year-Round Beds (ES, TH, SH)               float64
#                                                        ...
# Total Year-Round Beds (ES,TH)                         float64
# Total Non-DV Year-Round Beds (ES,TH)                  float64
# Total HMIS Year-Round Beds (ES,TH)                    float64
# HMIS Participation Rate (ES,TH)                        object
# Total Beds for Households without Children (ES,TH)    float64
# Length: 167, dtype: object

# %%
pit.dtypes
# Out:
# CoC Number                                               object
# CoC Name                                                 object
# CoC Category                                             object
# Overall Homeless                                        float64
# Overall Homeless - Under 18                             float64
#                                                          ...
# Sheltered ES Homeless Children of Parenting Youth       float64
# Sheltered TH Homeless Children of Parenting Youth       float64
# Sheltered Total Homeless Children of Parenting Youth    float64
# Unsheltered Homeless Children of Parenting Youth        float64
# year                                                      int64
# Length: 543, dtype: object

# %%
pit = pit.rename(columns={'year': 'Year'})

# %%
pit.columns, hic.columns
# Out:
# (Index(['CoC Number', 'CoC Name', 'CoC Category', 'Overall Homeless',
#         'Overall Homeless - Under 18', 'Overall Homeless - Age 18 to 24',
#         'Overall Homeless - Over 24', 'Overall Homeless - Female',
#         'Overall Homeless - Male', 'Overall Homeless - Transgender',
#         ...
#         'Sheltered ES Homeless Parenting Youth Age 18-24',
#         'Sheltered TH Homeless Parenting Youth Age 18-24',
#         'Sheltered Total Homeless Parenting Youth Age 18-24',
#         'Unsheltered Homeless Parenting Youth Age 18-24',
#         'Overall Homeless Children of Parenting Youth',
#         'Sheltered ES Homeless Children of Parenting Youth',
#         'Sheltered TH Homeless Children of Parenting Youth',
#         'Sheltered Total Homeless Children of Parenting Youth',
#         'Unsheltered Homeless Children of Parenting Youth', 'Year'],
#        dtype='object', length=543),
#  Index(['Year', 'CoC Number', 'Total Year-Round Beds (ES, TH, SH)',
# ...

# %%
hic = hic.dropna(subset=['CoC Number', 'Year'])
pit = pit.dropna(subset=['CoC Number', 'Year'])

# %%
df = hic.merge(pit, on=['CoC Number', 'Year'], how='inner', indicator=True)

# %%
df
# Out:
#       Year CoC Number  ... Unsheltered Homeless Children of Parenting Youth _merge
# 0     2020     AK-500  ...                                              0.0   both
# 1     2020     AK-501  ...                                              0.0   both
# 2     2020     AL-500  ...                                              0.0   both
# 3     2020     AL-501  ...                                              1.0   both
# 4     2020     AL-502  ...                                              0.0   both
# ...    ...        ...  ...                                              ...    ...
# 5426  2007     WV-500  ...                                              NaN   both
# 5427  2007     WV-501  ...                                              NaN   both
# 5428  2007     WV-503  ...                                              NaN   both
# 5429  2007     WV-508  ...                                              NaN   both
# ...

# %%
df.to_csv('/content/drive/MyDrive/DS4_project data/Final Data sets /pit_hic_merged.csv', index=False)

# %%
coc_year = df[['CoC Number', 'Year', '_merge']]
coc_year[coc_year['_merge']=='left_only']
# Out:
#      CoC Number  Year     _merge
# 213      MO-604  2020  left_only
# 391       Total  2020  left_only
# 547      MA-508  2019  left_only
# 553      MA-517  2019  left_only
# 585      MI-513  2019  left_only
# ...         ...   ...        ...
# 3155     PA-507  2013  left_only
# 3163     PA-602  2013  left_only
# 3195     TX-703  2013  left_only
# 3223     WA-507  2013  left_only
# 3234      Total  2013  left_only
#
# [123 rows x 3 columns]

# %%
pit
# Out:
#                                              CoC Number  ...  Year
# 0                                                AK-500  ...  2020
# 1                                                AK-501  ...  2020
# 2                                                AL-500  ...  2020
# 3                                                AL-501  ...  2020
# 4                                                AL-502  ...  2020
# ...                                                 ...  ...   ...
# 5492                                             WV-501  ...  2007
# 5493                                             WV-503  ...  2007
# 5494                                             WV-508  ...  2007
# 5495                                             WY-500  ...  2007
# 5498  a MO-604 covers territory in both Missouri and...  ...  2007
#
# [5471 rows x 543 columns]
